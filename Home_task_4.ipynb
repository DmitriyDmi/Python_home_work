# %% [markdown]
# Задача 22: Даны два неупорядоченных набора целых чисел (может быть, с повторениями). Выдать без повторений в порядке возрастания все те числа, которые встречаются в обоих наборах.
# Пользователь вводит 2 числа. n - кол-во элементов первого множества. m - кол-во элементов второго множества. Затем пользователь вводит сами элементы множеств.

# %%
import random
n1 = int(input('Введите длину 1го набора чисел: '))
n2 = int(input('Введите длину 2го набора чисел: '))
lst1 = [random.randint(0,20) for i in range(n1)]
lst2 = [random.randint(0,20) for i in range(n2)]
mng1 = set(lst1)
mng2 = set(lst2)
union_mng = mng1.intersection(mng2)
print(f'Первый набор чисел: {lst1}')
print(f'Второй набор чисел: {lst2}')
print(f'Множество первого набора: {mng1}')
print(f'Множество второго набора: {mng2}')
print(f'Множество значений имеющиеся в обоих наборах: {sorted(union_mng)}')
# Out:
# Введите длину 1го набора чисел: 23
# Введите длину 2го набора чисел: 26
# Первый набор чисел: [16, 7, 9, 11, 18, 18, 7, 2, 1, 13, 3, 0, 15, 15, 11, 12, 11, 5, 0, 18, 15, 9, 12]
# Второй набор чисел: [1, 15, 9, 17, 10, 0, 16, 2, 8, 6, 6, 12, 11, 0, 0, 10, 20, 14, 0, 7, 0, 6, 14, 18, 0, 14]
# Множество первого набора: {0, 1, 2, 3, 5, 7, 9, 11, 12, 13, 15, 16, 18}
# Множество второго набора: {0, 1, 2, 6, 7, 8, 9, 10, 11, 12, 14, 15, 16, 17, 18, 20}
# Множество значений имеющиеся в обоих наборах: [0, 1, 2, 7, 9, 11, 12, 15, 16, 18]

# %% [markdown]
# Задача 24: В фермерском хозяйстве в Карелии выращивают чернику. Она растет на круглой грядке, причем кусты высажены только по окружности. Таким образом, у каждого куста есть ровно два соседних. Всего на грядке растет N кустов.
# Эти кусты обладают разной урожайностью, поэтому ко времени сбора на них выросло различное число ягод – на i-ом кусте выросло РАНДОМНОЕ колличество ягод.
# В этом фермерском хозяйстве внедрена система автоматического сбора черники. Эта система состоит из управляющего модуля и нескольких собирающих модулей. Собирающий модуль за один заход, находясь непосредственно перед некоторым кустом, собирает ягоды с этого куста и с двух соседних с ним.
# Напишите программу для нахождения максимального числа ягод, которое может собрать за один заход собирающий модуль, находясь перед некоторым кустом заданной во входном файле грядки.

# %%
import random
n1 = int(input('Введите количество кустов: '))
lst1 = [random.randint(0,20) for i in range(n1)]
print(f'Список кустов с ягодами: {lst1}')
harvest_list = [(lst1[i] + lst1[(i + 1) % 6] + lst1[i - 1]) for i in range(n1)]
print(f'Сколько сможем собрать с куста и соседних к нему: {harvest_list}')
print(f'Максимально получится собрать: {max(harvest_list)}')
print(f'Индекс куста с которого(+соседних) можно собрать максимум: {harvest_list.index(max(harvest_list))}')
# Out:
# Введите количество кустов: 12
# Список кустов с ягодами: [18, 20, 19, 19, 13, 6, 12, 9, 20, 19, 15, 3]
# Сколько сможем собрать с куста и соседних к нему: [41, 57, 58, 51, 38, 37, 38, 40, 48, 52, 40, 36]
# Максимально получится собрать: 58
# Индекс куста с которого(+соседних) можно собрать максимум: 2
